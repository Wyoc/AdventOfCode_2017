# %% [markdown]
# # Advent of code - Day 1
# ## Inverse Captcha

# %% [markdown]
# ### Part 1

# %%
captcha  ="..."

# %%
solution = 0
for i in range(0, len(captcha)):
    if int(captcha[i]) == (int(captcha[i-1])):
        solution = solution + int(captcha[i])

# %%
solution
# Out:
# 1223

# %% [markdown]
# ### Part 2

# %%
captcha_p2="..."

# %%
solution_p2 = 0
for i in range(0, len(captcha_p2)):
    if (captcha_p2[i]) == ((captcha[i-int(len(captcha_p2)/2)])):
        solution_p2 = solution_p2 + int(captcha_p2[i])

# %%
solution_p2
# Out:
# 1284
